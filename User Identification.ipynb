# %% [markdown]
# # IMPORT LIBRARIES

# %%
import os
import torch
import pke
import json
import pandas as pd
import numpy as np
from nltk.metrics import edit_distance
import nltk
import re
import emoji
from sklearn.metrics.pairwise import cosine_similarity
import spacy
import pandasql as ps
import en_core_web_sm
from pke.lang import stopwords
from sentence_transformers import SentenceTransformer, util
from sentence_transformers.util import cos_sim
import torch.nn.functional as F
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
spacy.load("en_core_web_sm")

# %% [markdown]
# # METHOD 1: EDIT-DISTANCE

# %% [markdown]
# ## 1. Import facebook data

# %%
def read_valid_json_files_em(folder_path):
    json_files = [file for file in os.listdir(folder_path) if file.endswith('.json')]
    valid_data = []
    for json_file in json_files:
        try:
            with open(os.path.join(folder_path, json_file), 'r') as f:
                data = json.load(f)
                for file in data:                    
                    file['tw_id'] = json_file.split('_')[0]
                    file['file_num'] = json_file[-6]
                valid_data.extend(data)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON file: {json_file}")
    return valid_data

# %%
# Data extracting function
def extract_data_em(data):
    extracted_data = []
    for item in data:
        post_id = item.get("post_id")
        user_id = item.get("user_id")
        text = item.get("text")
        username = item.get("username")
        tw_id = item.get("tw_id")
        file_num = item.get("file_num")
        extracted_data.append({"post_id":post_id,
            "username": username, "user_id": user_id, "text": text
                               ,'tw_id':tw_id.lower(),"file_num": file_num
                               })
    return extracted_data

# %%
folder_path_fb =  r"fb1800raw"
valid_json_data_fb = read_valid_json_files_em(folder_path_fb)
extracted_data_fb = extract_data_em(valid_json_data_fb)
# Out:
# Skipping invalid JSON file: taylorswift_facebook_6.json

# %%
# Create a DataFrame from the extracted data
FB = pd.DataFrame(extracted_data_fb)

# %% [markdown]
# ## 2. Import X data

# %%
def read_valid_json_files_x(folder_path):
    json_files = [file for file in os.listdir(folder_path) if file.endswith('.json')]
    valid_data = []
    for json_file in json_files:
        try:
            with open(os.path.join(folder_path, json_file), 'r') as f:
                data = json.load(f)
                valid_data.extend(data)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON file: {json_file}")
    return valid_data

# %%
# Data extracting function
def extract_data_x(data):
    extracted_data = []
    for item in data:
        user_id = item.get("user_id")
        text = item.get("text")
        username = item.get("username")
        extracted_data.append({"username": username, "user_id": user_id, "text": text})
    return extracted_data

# %%
folder_path_x = r"tw300raw"
valid_json_data_x = read_valid_json_files_x(folder_path_x)
extracted_data_x = extract_data_x(valid_json_data_x)

# %%
X = pd.DataFrame(extracted_data_x)

# %% [markdown]
# ## 3. Calculate Edit-distance

# %%
X_check_edit = X[[
    'user_id','username'
    ]].drop_duplicates(subset=[
        'user_id','username'
        ]).reset_index()
X_check_edit
# Out:
#       index         user_id         username
# 0         0       billgates       Bill Gates
# 1      1001  carmeloanthony  Carmelo Anthony
# 2      2002      nickiminaj      Nicki Minaj
# 3      3003           oprah    Oprah Winfrey
# 4      4004         beyonce          BEYONCÉ
# ..      ...             ...              ...
# 270  260188   itsgabrielleu  Gabrielle Union
# 271  261189   shawnmichaels   Shawn Michaels
# 272  262190     rainnwilson      RainnWilson
# 273  263191      kerihilson      Keri Hilson
# 274  264192     rampalarjun     arjun rampal
#
# [275 rows x 3 columns]

# %%
FB_check_edit = FB[[
    'user_id','username','tw_id','file_num'
    ]].drop_duplicates(subset=[
        'user_id','username','tw_id','file_num'
        ]).reset_index()
FB_check_edit
# Out:
#        index          user_id                               username  \
# 0          0  587701401348302               Forever 5secondsofsummer
# 1          4  258244370945844  Ronaldinho: A Legend To Be Remembered
# 2         32             None  Ronaldinho: A Legend To Be Remembered
# 3         54  114824906744797           Brazil ; The Home Of Legends
# 4        254  100063455659640                    𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫
# ...      ...              ...                                    ...
# 2987  715358  100050617653542                                   Zeed
# 2988  715360  228908680640576                                   Zeed
# 2989  715362             None                                   Zeed
# 2990  715460     181938933887                       Insomniac Events
# 2991  716050  100044199167866                              YENGSTERS
#
#               tw_id file_num
# 0              5sos        4
# 1      10ronaldinho        5
# 2      10ronaldinho        5
# 3      10ronaldinho        3
# 4              5sos        3
# ...             ...      ...
# 2987           zedd        4
# 2988           zedd        4
# 2989           zedd        4
# 2990           zedd        3
# 2991  yengpluggedin        2
#
# [2992 rows x 5 columns]

# %%
df_edit = pd.DataFrame(columns=['fb_userid','fb_username','file_num','X_username','X_userid','edit_distance'])
for x in range(0,len(X_check_edit)):
    for fb in range(0,len(FB_check_edit)):
        if (X_check_edit['user_id'][x]==FB_check_edit['tw_id'][fb]):
            e = edit_distance(FB_check_edit['username'][fb]
                          ,X_check_edit['username'][x]) 
            df_edit = df_edit._append({
                                'fb_userid':FB_check_edit['user_id'][fb],
                                'fb_username': FB_check_edit['username'][fb],   
                                'file_num' : FB_check_edit['file_num'][fb],
                                'X_username': X_check_edit['username'][x],
                                'X_userid': X_check_edit['user_id'][x],
                                'edit_distance': e
                            }, ignore_index=True
                                    )

# %%
df_edit
# Out:
#             fb_userid                 fb_username file_num    X_username  \
# 0     100754822643960                  Bill Gates        3    Bill Gates
# 1     519305544814653  Conservative Tribune by WJ        4    Bill Gates
# 2     100044428239741                  Bill Gates        1    Bill Gates
# 3        216311481960                  Bill Gates        1    Bill Gates
# 4                None                  Bill Gates        1    Bill Gates
# ...               ...                         ...      ...           ...
# 2742  298696600251434                Arjun Rampal        1  arjun rampal
# 2743  191103734290916      Arjun Rampal Fans Club        6  arjun rampal
# 2744             None      Arjun Rampal Fans Club        6  arjun rampal
# 2745  100044453798606  ARJUN RAMPAL-LOVE YOU BHAI        2  arjun rampal
# 2746  100043876162121              Kangana Ranaut        5  arjun rampal
#
#          X_userid edit_distance
# 0       billgates             0
# 1       billgates            23
# 2       billgates             0
# 3       billgates             0
# 4       billgates             0
# ...           ...           ...
# 2742  rampalarjun             2
# 2743  rampalarjun            12
# 2744  rampalarjun            12
# 2745  rampalarjun            25
# 2746  rampalarjun            10
#
# [2747 rows x 6 columns]

# %%
import pandasql as ps
edit_result=ps.sqldf("""
    WITH N AS (
    SELECT *,RANK() OVER (PARTITION BY X_username
                                ORDER BY edit_distance ASC) RANKING
    FROM df_edit
    )
    SELECT X_username,X_userid, fb_username,fb_userid, file_num, edit_distance       
    FROM N         
    WHERE RANKING =1
""" , locals())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 import pandasql as ps
#       2 edit_result=ps.sqldf("""
#       3     WITH N AS (
#       4     SELECT *,RANK() OVER (PARTITION BY X_username
#    (...)
#      10     WHERE RANKING =1
#      11 """ , locals())
#
# ModuleNotFoundError: No module named 'pandasql'

# %%
edit_result

# %% [markdown]
# ## 4. Accuracy

# %%
cnt=ps.sqldf("""
    SELECT (COUNT(DISTINCT X_username))
    from true_label
""" , locals())

# %%
len(true_label['X_username'].unique())/len(X)

# %% [markdown]
# # METHOD 2: EMBEDDING VECTORS

# %% [markdown]
# ## 1. Import data

# %%
# Data reading function
def read_valid_json_files_em(folder_path):
    json_files = [file for file in os.listdir(folder_path) if file.endswith('.json')]
    valid_data = []
    for json_file in json_files:
        try:
            with open(os.path.join(folder_path, json_file), 'r') as f:
                data = json.load(f)
                for file in data:
                    file['file_name_1'] = json_file[:-16]
                    file['file_name_2'] = json_file[:]
                valid_data.extend(data)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON file: {json_file}")
    return valid_data

# %%
# Data extracting function
def extract_data_em(data):
    extracted_data = []
    for item in data:
        user_id = item.get("user_id")
        text = item.get("text")
        username = item.get("username")
        file_name_1 = item.get("file_name_1")
        file_name_2 = item.get("file_name_2")
        extracted_data.append({"username": username, "user_id": user_id, "text": text
                               ,"file_name_1": file_name_1, "file_name_2": file_name_2
                               })
    return extracted_data

# %%
def read_valid_json_files_em_x(folder_path):
    json_files = [file for file in os.listdir(folder_path) if file.endswith('.json')]
    valid_data = []
    for json_file in json_files:
        try:
            with open(os.path.join(folder_path, json_file), 'r') as f:
                data = json.load(f)
                valid_data.extend(data)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON file: {json_file}")
    return valid_data

# %%
def extract_data_em_x(data):
    extracted_data = []
    for item in data:
        user_id = item.get("user_id")
        text = item.get("text")
        username = item.get("username")
        extracted_data.append({"username": username, "user_id": user_id, "text": text})
    return extracted_data

# %%
folder_path_x_em = r"tw300raw"
valid_json_data_x_em = read_valid_json_files_em_x(folder_path_x_em)
extracted_data_x_em = extract_data_em_x(valid_json_data_x_em)

# %%
folder_path_fb_em = r"fb1800raw"
valid_json_data_fb_em = read_valid_json_files_em(folder_path_fb_em)
extracted_data_fb_em = extract_data_em(valid_json_data_fb_em)
# Out:
# Skipping invalid JSON file: taylorswift_facebook_6.json

# %%
# Create a DataFrame from the extracted data
df_fb_em = pd.DataFrame(extracted_data_fb_em)
df_x_em = pd.DataFrame(extracted_data_x_em)

# %%
df_x_em.sort_values("username")
# Out:
#        username     user_id                                               text
# 26939    50cent      50cent  Cyber Monday Sale 🎄35% OFF Storewide! Sale End...
# 27599    50cent      50cent  🔥 @unclemurda is currently #9 on Netflix ok i ...
# 27600    50cent      50cent  Happy C Day to my man @SnoopDogg wishing you m...
# 27601    50cent      50cent  It’s a good thing i don’t talk about things i ...
# 27602    50cent      50cent         BMF🔥My New #1 👏👏👏👏 https://t.co/3kb7bqZmCu
# ...         ...         ...                                                ...
# 132888       👼🏼  troyesivan                                     @strrrrre LMAO
# 132889       👼🏼  troyesivan                                       @YO_ONGl 🔥🔥🔥
# 132890       👼🏼  troyesivan                            https://t.co/IwbviS1spG
# 132877       👼🏼  troyesivan           And I’m happy :) https://t.co/LaCauzG2Jx
# 132596       👼🏼  troyesivan  @easysivans @turnerjoylynch Wait WHAT??? That’...
#
# [265193 rows x 3 columns]

# %%
df_fb_em.sort_values("username")
# Out:
#                    username          user_id  \
# 665929              1 9 9 6  102431234759221
# 665988              1 9 9 6  102431234759221
# 665989              1 9 9 6  102431234759221
# 665990              1 9 9 6  102431234759221
# 665991              1 9 9 6  102431234759221
# ...                     ...              ...
# 301     𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫  100063455659640
# 300     𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫  100063455659640
# 299     𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫  100063455659640
# 313     𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫  100063455659640
# 581     𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫  110497090720646
#
#                                                      text file_name_1  \
# 665929                               Young Keanu Reeves 🔥     Zendaya
# 665988  Zendaya ✨\n30 Epic Mistakes in the Most Popula...     Zendaya
# 665989                                      Red carpet 👀🔥     Zendaya
# 665990  Monica Bellucci & Alain Delon (1989) 🖤\nPopula...     Zendaya
# 665991  Jessica Biel and Chris Evans photographed on t...     Zendaya
# ...                                                   ...         ...
# 301     Join us for our special show 'The Feeling of F...        5SOS
# 300                                     JET BLACK HEART🖤🖤        5SOS
# 299                                      Jet Black Heart🖤        5SOS
# 313                                   The Summer Brothers        5SOS
# 581                 make me choose between two 5sos songs        5SOS
#
#                     file_name_2
# 665929  Zendaya_facebook_3.json
# 665988  Zendaya_facebook_3.json
# 665989  Zendaya_facebook_3.json
# 665990  Zendaya_facebook_3.json
# 665991  Zendaya_facebook_3.json
# ...                         ...
# 301        5SOS_facebook_3.json
# 300        5SOS_facebook_3.json
# 299        5SOS_facebook_3.json
# 313        5SOS_facebook_3.json
# 581        5SOS_facebook_3.json
#
# [716650 rows x 5 columns]

# %% [markdown]
# ## 2. Clean text data

# %%
df_fb_em.isnull().sum()
# Out:
# username          0
# user_id        2874
# text              0
# file_name_1       0
# file_name_2       0
# dtype: int64

# %%
df_fb_em[df_fb_em['user_id'].isnull()]
# Out:
#                                      username user_id  \
# 32      Ronaldinho: A Legend To Be Remembered    None
# 45      Ronaldinho: A Legend To Be Remembered    None
# 47      Ronaldinho: A Legend To Be Remembered    None
# 2213                            Luke Hemmings    None
# 4726                             Ashton Irwin    None
# ...                                       ...     ...
# 713388                           Jessica Alba    None
# 715362                                   Zeed    None
# 715443                                   Zeed    None
# 715446                                   Zeed    None
# 715459                                   Zeed    None
#
#                                                      text   file_name_1  \
# 32      This page is back up and running! What do you ...  10Ronaldinho
# 45                                                         10Ronaldinho
# 47                                                         10Ronaldinho
# 2213                                                               5SOS
# 4726                                                         Ashton5SOS
# ...                                                   ...           ...
# 713388                                                         ZacEfron
# 715362                                                             Zedd
# 715443  Zeed added 12 new photos.\nMay 18, 2014 at 4:0...          Zedd
# 715446  Zeed added 8 new photos.\nMay 13, 2014 at 8:45...          Zedd
# 715459                                          Zaslavski          Zedd
#
#                          file_name_2
# 32      10Ronaldinho_facebook_5.json
# 45      10Ronaldinho_facebook_5.json
# 47      10Ronaldinho_facebook_5.json
# 2213            5SOS_facebook_2.json
# 4726      Ashton5SOS_facebook_1.json
# ...                              ...
# 713388      ZacEfron_facebook_4.json
# 715362          Zedd_facebook_4.json
# 715443          Zedd_facebook_4.json
# 715446          Zedd_facebook_4.json
# 715459          Zedd_facebook_4.json
#
# [2874 rows x 5 columns]

# %%
df_fb_em['user_id'] = df_fb_em['user_id'].ffill()

# %%
df_fb_em.isnull().sum()
# Out:
# username       0
# user_id        0
# text           0
# file_name_1    0
# file_name_2    0
# dtype: int64

# %%
df_fb_em['text'] = df_fb_em['text'].dropna()

# %%
df_x_em['text'] = df_x_em['text'].dropna()

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")

from nltk.corpus import stopwords
import string

stopword=set(stopwords.words('english'))

def clean(text):
    # Chuyển đổi văn bản thành chữ thường
    text = str(text).lower()
    # Loại bỏ các ký tự trong dấu ngoặc vuông
    text = re.sub('\[.*?\]', '', text)
    # Loại bỏ các đường dẫn web
    text = re.sub('https?://\S+|www\.\S+', '', text)
    # Loại bỏ các thẻ HTML
    text = re.sub('<.*?>+', '', text)
    # Loại bỏ các dấu câu
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    # Loại bỏ các ký tự xuống dòng
    text = re.sub('\n', '', text)
    # Loại bỏ các từ có chứa số
    text = re.sub('\w*\d\w*', '', text)
    # Loại bỏ emoji
    text = emoji.replace_emoji(text)
    # Loại bỏ các từ dừng, ví dụ như là, của, và.
    # Từ dừng là những từ phổ biến nhưng không mang nhiều ý nghĩa cho văn bản.
    text = [word for word in text.split(' ') if word not in stopword]
    # Nối lại các từ còn lại thành một chuỗi văn bản
    text = " ".join(text)
    # Áp dụng thuật toán stemmer để rút gọn các từ về dạng gốc,
    # ví dụ như học -> học, học sinh -> học, học tập -> học.
    # Stemmer là một công cụ để giảm thiểu số lượng các từ khác nhau nhưng có cùng nghĩa trong văn bản.
    text = [stemmer.stem(word) for word in text.split(' ')]
    # Nối lại các từ đã được stem thành một chuỗi văn bản
    text = " ".join(text)
    return text
# Out:
# [nltk_data] Downloading package stopwords to /home/jupyter-
# [nltk_data]     hocnv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_fb_em["text"] = df_fb_em["text"].apply(clean)

# %%
df_x_em["text"] = df_x_em["text"].apply(clean)

# %% [markdown]
# ## 3. Combine text

# %% [markdown]
# #### 3.1. Embeddings 1: gte-large

# %%
df_fb_gte = df_fb_em.groupby("username").head(100)

# %%
df_x_gte = df_x_em.groupby("username").head(100)

# %%
df_fb_gte = df_fb_gte.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
df_x_gte = df_x_gte.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
fb_text_list = df_fb_gte["text"].tolist()

# %%
x_text_list = df_x_gte["text"].tolist()

# %%
model = SentenceTransformer('thenlper/gte-large')

# %%
embeddings_fb_gte = model.encode(fb_text_list, convert_to_tensor=True)
embeddings_x_gte = model.encode(x_text_list, convert_to_tensor=True)

# %%
embeddings_fb_np = embeddings_fb_gte.cpu().detach().numpy()
embeddings_x_np = embeddings_x_gte.cpu().detach().numpy()

# %%
cosine_scores = util.cos_sim(embeddings_x_np, embeddings_fb_np)

# %%
#cosine_scores_tensor = torch.tensor(cosine_scores)
cosine_scores = cosine_scores.clone().detach()
max_values, max_indices = torch.max(cosine_scores, dim=1)

# %%
df_x_gte
# Out:
#                   username                                               text
# 0                   50cent  cyber monday sale  storewid sale end tonight s...
# 1                   @jason  mikesalguero think awesom share calendar revie...
# 2                   A Lord  grate it suppos wow excel kind weekend stay sa...
# 3               A.R.Rahman  happi birthday udhaystalin glad part mamannan ...
# 4              Adam Levine   ojala maluma therudeboyz  offici video stream...
# ..                     ...                                                ...
# 270  tyler oakley (parody)  oh wow  shaniatwain lakestreetd  forget that a...
# 271                     ye    first time maralago  rain traffic can't beli...
# 272                   zayn  ask collabor celebr jimihendrix  birthday unex...
# 273        zooey deschanel  love entir convers  im donat  join let know re...
# 274                     👼🏼  blast perform  event kick miami art week watch...
#
# [275 rows x 2 columns]

# %%
df_fb_gte
# Out:
#                                  username  \
# 0                                 1 9 9 6
# 1                                   1997.
# 2     44th POTUS, his story made history.
# 3                     5 Seconds of Summer
# 4                 5 Seconds of Summer Fam
# ...                                   ...
# 1524                   𝑱𝒖𝒔𝒕𝒊𝒏 𝑩𝒊𝒆𝒃𝒆𝒓 𝑭𝒂𝒏𝒔
# 1525                         𝓩𝓮𝓷𝓭𝓪𝔂𝓪 𝓕𝓪𝓷𝓼
# 1526                                𝙄𝙘𝙤𝙣𝙨
# 1527            𝚅 𝙴 𝚁 𝚂 𝙴 𝚁 𝙴 𝙿 𝚄 𝙱 𝙻 𝙸 𝙲
# 1528                  𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫
#
#                                                    text
# 0     cameron diaz mask   popular actor   chang    s...
# 1     angelina joli  angelina joli  leonardo dicapri...
# 2     queen elizabeth alexandra mari ii majesti made...
# 3      merch  grab  feel  love  amazon music silver ...
# 4     nice meet guy  hometim   your done peopl keep ...
# ...                                                 ...
# 1524  “a gentl word kind look goodnatur smile work w...
# 1525                 wikiofwitchercomdemi moor look ...
# 1526   bella hadid sprayon dress coperni  show alexa...
# 1527  somewher knowkeanelyricsi walk across empti la...
# 1528   merch  grab   second summer new album  back  ...
#
# [1529 rows x 2 columns]

# %%
df_x_gte = df_x_gte.assign(cosine=max_values, position=max_indices)

# %%
df_x_gte["fb_username"] = df_x_gte["position"].apply(lambda x: df_fb_gte["username"][x])

# %%
df_x_gte
# Out:
#                   username                                               text  \
# 0                   50cent  cyber monday sale  storewid sale end tonight s...
# 1                   @jason  mikesalguero think awesom share calendar revie...
# 2                   A Lord  grate it suppos wow excel kind weekend stay sa...
# 3               A.R.Rahman  happi birthday udhaystalin glad part mamannan ...
# 4              Adam Levine   ojala maluma therudeboyz  offici video stream...
# ..                     ...                                                ...
# 270  tyler oakley (parody)  oh wow  shaniatwain lakestreetd  forget that a...
# 271                     ye    first time maralago  rain traffic can't beli...
# 272                   zayn  ask collabor celebr jimihendrix  birthday unex...
# 273        zooey deschanel  love entir convers  im donat  join let know re...
# 274                     👼🏼  blast perform  event kick miami art week watch...
#
#        cosine  position                  fb_username
# 0    0.890400      1212                         Shaq
# 1    0.874581       200                 CNBC Make It
# 2    0.900617       790               Lewis_Hamilton
# 3    0.898668        18                   A.R.Rahman
# 4    0.952626        34                  Adam Levine
# ..        ...       ...                          ...
# 270  0.885632       734             Khloé Kardashian
# 271  0.889856       150  Best quotes by Steve Harvey
# 272  0.895589      1335  The Pillowtalker Zayn Malik
# 273  0.911454      1505              Zooey Deschanel
# 274  0.916216      1405                  Troye Sivan
#
# [275 rows x 5 columns]

# %%
result_gte = df_x_gte[df_x_gte["username"] == df_x_gte["fb_username"]]

# %%
fbb = df_fb_em.drop_duplicates("username")

# %%
xx = df_x_em.drop_duplicates("username")

# %%
dc = pd.merge(fbb, xx, right_on="username", left_on='username', how='inner')

# %%
dc
# Out:
#                 username        user_id_x  \
# 0          Luke Hemmings  100044531975401
# 1             A.R.Rahman  696457343797395
# 2           Ashton Irwin  100044587322642
# 3           Angel Locsin  100044605471738
# 4    Neil Patrick Harris  100044619390816
# ..                   ...              ...
# 210        Jonathan Ross  539314996150555
# 211   Christina Aguilera  100044245098301
# 212     Yeng Constantino  100044560950813
# 213            Zac Efron  112576674764564
# 214                 Zedd  100044240175837
#
#                                                 text_x    file_name_1  \
# 0    don't think lip ring work  eye mask certain th...           5SOS
# 1                                                            arrahman
# 2     year anniversari superbloom kick back video c...     Ashton5SOS
# 3                top rate phenomen tatak angel locsin     143redangel
# 4    oh hi here sip whiski scotland complex delici ...    ActuallyNPH
# ..                                                 ...            ...
# 210                                                             wossy
# 211  la reina  billboard latinth queen  billboard l...          xtina
# 212  vote  excellenceoctob   pm ·last chanc cast vo...  YengPLUGGEDin
# 213  death majesti queen elizabeth profound sad mom...       ZacEfron
# 214  tune octob  special perform maren morri fallon...           Zedd
#
#                        file_name_2      user_id_y  \
# 0             5SOS_facebook_2.json       luke5sos
# 1         arrahman_facebook_3.json       arrahman
# 2       Ashton5SOS_facebook_1.json     ashton5sos
# 3      143redangel_facebook_3.json    143redangel
# 4      ActuallyNPH_facebook_1.json    actuallynph
# ..                             ...            ...
# 210          wossy_facebook_3.json          wossy
# 211          xtina_facebook_1.json          xtina
# 212  YengPLUGGEDin_facebook_1.json  yengpluggedin
# 213       ZacEfron_facebook_2.json       zacefron
# 214           Zedd_facebook_1.json           zedd
#
#                                                 text_y
# 0                          fave video we'v ever done
# 1    happi birthday udhaystalin glad part mamannan ...
# 2    hotel room power stanc see tonight gold coast ...
# 3     new vlog drop theangelandneilchannel today  s...
# 4    tomorrow  anniversari wondercad onedercad chee...
# ..                                                 ...
# 210                     stephenk bullshit hate said si
# 211                                         aftermath
# 212                                    love yengster
# 213  let fix keep make beauti movi togeth love guy ...
# 214                              couragejd proud buddi
#
# [215 rows x 7 columns]

# %% [markdown]
# #### 3.2. Accuracy 1: gte-large

# %%
print("Accuracy of gte-large = {0}%".format(round((result_gte.shape[0] / dc.shape[0]) * 100, 5)))
# Out:
# Accuracy of gte-large = 53.95349%

# %% [markdown]
# #### 3.3. Embeddings 2: e5-small-v2

# %%
model_e = SentenceTransformer('intfloat/e5-small-v2')

# %%
df_fb_e = df_fb_em.groupby("username").head(100)

# %%
df_x_e = df_x_em.groupby("username").head(100)

# %%
df_fb_e = df_fb_e.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
df_x_e = df_x_e.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
fb_text_list_e = df_fb_e["text"].tolist()

# %%
x_text_list_e = df_x_e["text"].tolist()

# %%
embeddings_x_e = model_e.encode(x_text_list_e, normalize_embeddings=True, convert_to_tensor=True)
embeddings_fb_e = model_e.encode(fb_text_list_e, normalize_embeddings=True, convert_to_tensor=True)

# %%
embeddings_fb_e = embeddings_fb_e.cpu().detach().numpy()
embeddings_x_e = embeddings_x_e.cpu().detach().numpy()

# %%
cosine_scores_e = util.cos_sim(embeddings_x_e, embeddings_fb_e)

# %%
cosine_scores_e = cosine_scores_e.clone().detach()
max_values_e, max_indices_e = torch.max(cosine_scores_e, dim=1)

# %%
df_x_e = df_x_e.assign(cosine=max_values_e, position=max_indices_e)

# %%
df_x_e["fb_username"] = df_x_e["position"].apply(lambda x: df_fb_e["username"][x])

# %%
result_e = df_x_e[df_x_e["username"] == df_x_e["fb_username"]]

# %% [markdown]
# #### 3.4. Accuracy 2: e5-small-v2

# %%
print("Accuracy of e5-small-v2 = {0}%".format(round(result_e.shape[0] / 215 * 100, 5)))
# Out:
# Accuracy of e5-small-v2 = 41.86047%

# %% [markdown]
# #### 3.5. Embeddings 3: GIST-small-Embedding-v0

# %%
model_gist = SentenceTransformer("avsolatorio/GIST-small-Embedding-v0", revision=None)

# %%
df_fb_gist_cf = df_fb_em.groupby("username").head(100)

# %%
df_x_gist_cf = df_x_em.groupby("username").head(100)

# %%
df_fb_gist_cf = df_fb_gist_cf.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
df_x_gist_cf = df_x_gist_cf.groupby('username')['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
fb_gist_list_cf = df_fb_gist_cf["text"].tolist()

# %%
x_gist_list_cf = df_x_gist_cf["text"].tolist()

# %%
embeddings_x_gist = model_gist.encode(x_gist_list_cf, convert_to_tensor=True)
embeddings_fb_gist = model_gist.encode(fb_gist_list_cf, convert_to_tensor=True)

# %%
embeddings_fb_gist = embeddings_fb_gist.cpu().detach().numpy()
embeddings_x_gist = embeddings_x_gist.cpu().detach().numpy()

# %%
cosine_scores_gist = util.cos_sim(embeddings_x_gist, embeddings_fb_gist)

# %%
cosine_scores_gist = cosine_scores_gist.clone().detach()
max_values_gist, max_indices_gist = torch.max(cosine_scores_gist, dim=1)

# %%
df_x_gist_cf = df_x_gist_cf.assign(cosine=max_values_gist, position=max_indices_gist)

# %%
df_x_gist_cf["fb_username"] = df_x_gist_cf["position"].apply(lambda x: df_fb_gist_cf["username"][x])

# %%
result_gist = df_x_gist_cf[df_x_gist_cf["username"] == df_x_gist_cf["fb_username"]]
result_gist
# Out:
#              username                                               text  \
# 4         Adam Levine   ojala maluma therudeboyz  offici video stream...
# 5               Adele   weekend   dress nine nye would love come woul...
# 7          Alia Bhatt      travel ab badal gaya haibadloapnaexperi ad...
# 10     Andrés Iniesta  mucha felicidad fcbarcelona   vamo españa fifa...
# 14   Anthony Bourdain  song score tonight hong kong partsunknowncnn g...
# ..                ...                                                ...
# 243       Tyler Perry  tonight  episod sistasonbet air believ  episod...
# 246  Victoria Beckham  new musthav bag holiday seasonth fun size mini...
# 247  Victoria Justice    ain't parti like diwali parti cuz diwali par...
# 248       Virat Kohli  earn  cr peer period  year invest upskil  zero...
# 251      Wayne Rooney   thank everyth mate  manutdmumbai pleasur meet...
#
#        cosine  position       fb_username
# 4    0.943540        34       Adam Levine
# 5    0.923433        39             Adele
# 7    0.934073        49        Alia Bhatt
# 10   0.856171        75    Andrés Iniesta
# 14   0.880438        96  Anthony Bourdain
# ..        ...       ...               ...
# 243  0.936446      1413       Tyler Perry
# 246  0.884670      1433  Victoria Beckham
# 247  0.928102      1438  Victoria Justice
# 248  0.903246      1445       Virat Kohli
# 251  0.938992      1466      Wayne Rooney
#
# [97 rows x 5 columns]

# %% [markdown]
# #### 3.6. Accuracy 3: GIST-small-Embedding-v0

# %%
print("Accuracy of GIST-small-Embedding-v0 model is {0}%".format(round(result_gist.shape[0] / 215 * 100,5)))
# Out:
# Accuracy of GIST-small-Embedding-v0 model is 45.11628%

# %% [markdown]
# ## 4. Compare file_name

# %% [markdown]
# #### 4.1. Embeddings 1: e5-small-v2

# %%
model_e5 = SentenceTransformer('intfloat/e5-small-v2')

# %%
df_fb_gist = df_fb_em.groupby('user_id').agg({
    'username': 'first',  # Chọn giá trị đầu tiên cho 'username'
    'text': lambda x: ' '.join(x),  # Kết hợp các giá trị trong 'text'
    'file_name_1': 'first',
    'file_name_2' : 'first'# Chọn giá trị đầu tiên cho 'file_name'
}).reset_index()
df_fb_gist
# Out:
#               user_id                                username  \
# 0           719210943                          Farah Khan Ali
# 1     100024590681364  Shraddha kapoor The Adorable Actress 2
# 2     100024879207187                      One Direction News
# 3     100028312309284                         Skandalous Talk
# 4     100028409966696                      A DAY ON THE GREEN
# ...               ...                                     ...
# 2269       9899376497                               John Cena
# 2270       9934379006                        Miranda Cosgrove
# 2271      99423386070                          Florida Gators
# 2272       9964154115                          Channing Tatum
# 2273      99958504850                          Cookie Johnson
#
#                                                    text      file_name_1  \
# 0      year begin high note thank jaipurjewellerysho...     TheFarahKhan
# 1     shraddhakapoor  shraddhakapoorfan shraddhakapo...   ShraddhaKapoor
# 2     harri style olivia wild arriv don't worri darl...    NiallOfficial
# 3      streamspaceseptemb   pm · rock kevin hart lik...        SnoopDogg
# 4                           sat mar   adam  shine light        johngreen
# ...                                                 ...              ...
# 2269  john cena vs batista alexa bliss vs bayley rel...         JohnCena
# 2270  witch tonight   today la  let come togeth reth...  MirandaCosgrove
# 2271  still danc congrat gatorsvb advanc round  home...     official_flo
# 2272  get back speed ride year still need get knee b...    channingtatum
# 2273  reflect honor resili communiti continu fight t...     MagicJohnson
#
#                           file_name_2
# 0        TheFarahKhan_facebook_6.json
# 1      ShraddhaKapoor_facebook_4.json
# 2       NiallOfficial_facebook_5.json
# 3           SnoopDogg_facebook_4.json
# 4           johngreen_facebook_6.json
# ...                               ...
# 2269         JohnCena_facebook_1.json
# 2270  MirandaCosgrove_facebook_1.json
# 2271     official_flo_facebook_4.json
# 2272    channingtatum_facebook_1.json
# 2273     MagicJohnson_facebook_2.json
#
# [2274 rows x 5 columns]

# %%
df_x_gist = df_x_em.groupby('user_id').agg({
    'username': 'first',
    'text': lambda x: ' '.join(x)
}).reset_index()
df_x_gist
# Out:
#             user_id             username  \
# 0      10ronaldinho           Ronaldinho
# 1       143redangel         Angel Locsin
# 2            50cent               50cent
# 3       actuallynph  Neil Patrick Harris
# 4        adamlevine          Adam Levine
# ..              ...                  ...
# 270        zacefron            Zac Efron
# 271       zaynmalik                 zayn
# 272            zedd                 Zedd
# 273         zendaya              Zendaya
# 274  zooeydeschanel      zooey deschanel
#
#                                                   text
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
# [275 rows x 3 columns]

# %%
fb_text_list = df_fb_gist["text"].tolist()
x_text_list = df_x_gist["text"].tolist()

# %%
embeddings_fb_e5 = model_e5.encode(fb_text_list, convert_to_tensor=True)
embeddings_x_e5 = model_e5.encode(x_text_list, convert_to_tensor=True)

# %%
embeddings_fb_e5 = embeddings_fb_e5.cpu().detach().numpy()
embeddings_x_e5 = embeddings_x_e5.cpu().detach().numpy()

# %%
cc = embeddings_fb_e5.tolist()
gg = embeddings_x_e5.tolist()

# %%
df_fb_gist["text_vector"] = cc

# %%
df_fb_gist
# Out:
#               user_id                                username  \
# 0           719210943                          Farah Khan Ali
# 1     100024590681364  Shraddha kapoor The Adorable Actress 2
# 2     100024879207187                      One Direction News
# 3     100028312309284                         Skandalous Talk
# 4     100028409966696                      A DAY ON THE GREEN
# ...               ...                                     ...
# 2269       9899376497                               John Cena
# 2270       9934379006                        Miranda Cosgrove
# 2271      99423386070                          Florida Gators
# 2272       9964154115                          Channing Tatum
# 2273      99958504850                          Cookie Johnson
#
#                                                    text      file_name_1  \
# 0      year begin high note thank jaipurjewellerysho...     TheFarahKhan
# 1     shraddhakapoor  shraddhakapoorfan shraddhakapo...   ShraddhaKapoor
# 2     harri style olivia wild arriv don't worri darl...    NiallOfficial
# 3      streamspaceseptemb   pm · rock kevin hart lik...        SnoopDogg
# 4                           sat mar   adam  shine light        johngreen
# ...                                                 ...              ...
# 2269  john cena vs batista alexa bliss vs bayley rel...         JohnCena
# 2270  witch tonight   today la  let come togeth reth...  MirandaCosgrove
# 2271  still danc congrat gatorsvb advanc round  home...     official_flo
# 2272  get back speed ride year still need get knee b...    channingtatum
# 2273  reflect honor resili communiti continu fight t...     MagicJohnson
#
#                           file_name_2  \
# 0        TheFarahKhan_facebook_6.json
# 1      ShraddhaKapoor_facebook_4.json
# 2       NiallOfficial_facebook_5.json
# 3           SnoopDogg_facebook_4.json
# 4           johngreen_facebook_6.json
# ...                               ...
# 2269         JohnCena_facebook_1.json
# 2270  MirandaCosgrove_facebook_1.json
# 2271     official_flo_facebook_4.json
# 2272    channingtatum_facebook_1.json
# 2273     MagicJohnson_facebook_2.json
#
#                                             text_vector
# 0     [-0.08209969848394394, 0.06346770375967026, 0....
# 1     [-0.11407114565372467, 0.04150240495800972, -0...
# 2     [-0.0811256393790245, 0.025075891986489296, 0....
# 3     [-0.07153625786304474, 0.050333671271800995, 0...
# 4     [-0.09362127631902695, 0.017025548964738846, 0...
# ...                                                 ...
# 2269  [-0.14030547440052032, 0.033722955733537674, 0...
# 2270  [-0.06961727887392044, 0.06061193719506264, 0....
# 2271  [-0.12481772154569626, 0.029234565794467926, 0...
# 2272  [-0.08227701485157013, 0.056930433958768845, 0...
# 2273  [-0.10766727477312088, 0.06107241287827492, 0....
#
# [2274 rows x 6 columns]

# %%
df_x_gist["text_vector"] = gg

# %%
df_x_gist
# Out:
#             user_id             username  \
# 0      10ronaldinho           Ronaldinho
# 1       143redangel         Angel Locsin
# 2            50cent               50cent
# 3       actuallynph  Neil Patrick Harris
# 4        adamlevine          Adam Levine
# ..              ...                  ...
# 270        zacefron            Zac Efron
# 271       zaynmalik                 zayn
# 272            zedd                 Zedd
# 273         zendaya              Zendaya
# 274  zooeydeschanel      zooey deschanel
#
#                                                   text  \
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
#                                            text_vector
# 0    [-0.11690832674503326, 0.06458992511034012, 0....
# 1    [-0.06213437765836716, 0.038958705961704254, 0...
# 2    [-0.09256376326084137, 0.028269054368138313, 0...
# 3    [-0.09586158394813538, 0.03052220307290554, 0....
# 4    [-0.06409592181444168, 0.06178886815905571, 0....
# ..                                                 ...
# 270  [-0.09526766091585159, 0.037829067558050156, 0...
# 271  [-0.09214373677968979, 0.04666445031762123, 0....
# 272  [-0.08149664103984833, 0.049187108874320984, 0...
# 273  [-0.09616198390722275, 0.06231871619820595, 0....
# 274  [-0.08643965423107147, 0.041922636330127716, 0...
#
# [275 rows x 4 columns]

# %%
data = []
for x in range(len(df_x_gist)):
    for fb in range(len(df_fb_gist)):
        if df_x_gist["user_id"][x] == df_fb_gist["file_name_1"][fb].lower():
            cosine = util.cos_sim(df_x_gist["text_vector"][x], df_fb_gist["text_vector"][fb]).item()
            data.append({
                "fb_username": df_fb_gist["username"][fb],
                "x_username": df_x_gist["username"][x],
                "x_userid": df_x_gist["user_id"][x],
                "file_name": df_fb_gist["file_name_2"][fb],
                "cosine": cosine
            })

# %%
data_finish = pd.DataFrame(data)

# %%
data_finish
# Out:
#                                             fb_username       x_username  \
# 0                                Futrj Football Channel       Ronaldinho
# 1                                     Ronaldinho Gaúcho       Ronaldinho
# 2     Trener Dryblingu Piłkarskiego - Piotr "Olo" Ol...       Ronaldinho
# 3                                              Raphinha       Ronaldinho
# 4                                              Raphinha       Ronaldinho
# ...                                                 ...              ...
# 2012                                    Zooey Deschanel  zooey deschanel
# 2013                              Jonathan Silver Scott  zooey deschanel
# 2014                         I Love you Zooey Deschanel  zooey deschanel
# 2015                      Emily Deschanel Fanpage En/Sk  zooey deschanel
# 2016                                Sarah Nelson Makeup  zooey deschanel
#
#             x_userid                       file_name    cosine
# 0       10ronaldinho    10Ronaldinho_facebook_6.json  0.917860
# 1       10ronaldinho    10Ronaldinho_facebook_1.json  0.933636
# 2       10ronaldinho    10Ronaldinho_facebook_4.json  0.853782
# 3       10ronaldinho    10Ronaldinho_facebook_2.json  0.790712
# 4       10ronaldinho    10Ronaldinho_facebook_2.json  0.917504
# ...              ...                             ...       ...
# 2012  zooeydeschanel  ZooeyDeschanel_facebook_1.json  0.936490
# 2013  zooeydeschanel  ZooeyDeschanel_facebook_3.json  0.935158
# 2014  zooeydeschanel  ZooeyDeschanel_facebook_4.json  0.908975
# 2015  zooeydeschanel  ZooeyDeschanel_facebook_6.json  0.901184
# 2016  zooeydeschanel  ZooeyDeschanel_facebook_5.json  0.898605
#
# [2017 rows x 5 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

data = []

# Vectorize text data for both df_x_gist and df_fb_gist
vectorizer = TfidfVectorizer()
tfidf_matrix_x = vectorizer.fit_transform(df_x_gist["text"])
tfidf_matrix_fb = vectorizer.transform(df_fb_gist["text"])

# Loop through each pair of texts
for x in range(len(df_x_gist)):
    for fb in range(len(df_fb_gist)):
        if df_x_gist["user_id"][x] == df_fb_gist["file_name_1"][fb].lower():
            # Calculate cosine similarity
            cosine = cosine_similarity(tfidf_matrix_x[x], tfidf_matrix_fb[fb])[0][0]
            data.append({
                "fb_username": df_fb_gist["username"][fb],
                "x_username": df_x_gist["username"][x],
                "x_userid": df_x_gist["user_id"][x],
                "file_name": df_fb_gist["file_name_2"][fb],
                "cosine": cosine
            })

# %%
data_finish = data_finish.groupby("x_userid").agg({
    "fb_username" : "first",
    "cosine" : "max",
    "file_name" : "first"
})

# %%
data_finish
# Out:
#                                 fb_username    cosine  \
# x_userid
# 10ronaldinho         Futrj Football Channel  0.933636
# 143redangel         Angel Locsin Supporters  0.918688
# 50cent                              50 Cent  0.909899
# actuallynph             Neil Patrick Harris  0.937589
# adamlevine                         Maroon 5  0.945554
# ...                                     ...       ...
# zacefron                          Zac Efron  0.940685
# zaynmalik       The Pillowtalker Zayn Malik  0.913868
# zedd                                   Zedd  0.912794
# zendaya                    Celebrity Ladies  0.931439
# zooeydeschanel        Jonathan Silver Scott  0.937947
#
#                                      file_name
# x_userid
# 10ronaldinho      10Ronaldinho_facebook_6.json
# 143redangel        143redangel_facebook_4.json
# 50cent                  50cent_facebook_1.json
# actuallynph        ActuallyNPH_facebook_1.json
# adamlevine          adamlevine_facebook_3.json
# ...                                        ...
# zacefron              ZacEfron_facebook_1.json
# zaynmalik            zaynmalik_facebook_4.json
# zedd                      Zedd_facebook_1.json
# zendaya                Zendaya_facebook_4.json
# zooeydeschanel  ZooeyDeschanel_facebook_3.json
#
# [269 rows x 3 columns]

# %%
true_e5 = data_finish[data_finish["file_name"].str[-6] == "1"]

# %% [markdown]
# #### 4.2. Accuracy 1: e5-small-v2

# %%
print("Accuracy of e5-small-v2 model is {0}%".format(round(true_e5.shape[0] / data_finish.shape[0] * 100, 5)))
# Out:
# Accuracy of e5-small-v2 model is 63.56877%

# %% [markdown]
# #### 4.3. Embeddings 2: GIST-small-Embedding-v0

# %%
model_gist = SentenceTransformer("avsolatorio/GIST-small-Embedding-v0", revision=None)

# %%
df_fb_gist = df_fb_em.groupby('user_id').agg({
    'username': 'first',
    'text': lambda x: ' '.join(x),
    'file_name_1': 'first',
    'file_name_2' : 'first'
}).reset_index()
df_fb_gist
# Out:
#               user_id                                username  \
# 0           719210943                          Farah Khan Ali
# 1     100024590681364  Shraddha kapoor The Adorable Actress 2
# 2     100024879207187                      One Direction News
# 3     100028312309284                         Skandalous Talk
# 4     100028409966696                      A DAY ON THE GREEN
# ...               ...                                     ...
# 2269       9899376497                               John Cena
# 2270       9934379006                        Miranda Cosgrove
# 2271      99423386070                          Florida Gators
# 2272       9964154115                          Channing Tatum
# 2273      99958504850                          Cookie Johnson
#
#                                                    text      file_name_1  \
# 0      year begin high note thank jaipurjewellerysho...     TheFarahKhan
# 1     shraddhakapoor  shraddhakapoorfan shraddhakapo...   ShraddhaKapoor
# 2     harri style olivia wild arriv don't worri darl...    NiallOfficial
# 3      streamspaceseptemb   pm · rock kevin hart lik...        SnoopDogg
# 4                           sat mar   adam  shine light        johngreen
# ...                                                 ...              ...
# 2269  john cena vs batista alexa bliss vs bayley rel...         JohnCena
# 2270  witch tonight   today la  let come togeth reth...  MirandaCosgrove
# 2271  still danc congrat gatorsvb advanc round  home...     official_flo
# 2272  get back speed ride year still need get knee b...    channingtatum
# 2273  reflect honor resili communiti continu fight t...     MagicJohnson
#
#                           file_name_2
# 0        TheFarahKhan_facebook_6.json
# 1      ShraddhaKapoor_facebook_4.json
# 2       NiallOfficial_facebook_5.json
# 3           SnoopDogg_facebook_4.json
# 4           johngreen_facebook_6.json
# ...                               ...
# 2269         JohnCena_facebook_1.json
# 2270  MirandaCosgrove_facebook_1.json
# 2271     official_flo_facebook_4.json
# 2272    channingtatum_facebook_1.json
# 2273     MagicJohnson_facebook_2.json
#
# [2274 rows x 5 columns]

# %%
df_x_gist = df_x_em.groupby('user_id').agg({
    'username': 'first',
    'text': lambda x: ' '.join(x)
}).reset_index()
df_x_gist
# Out:
#             user_id             username  \
# 0      10ronaldinho           Ronaldinho
# 1       143redangel         Angel Locsin
# 2            50cent               50cent
# 3       actuallynph  Neil Patrick Harris
# 4        adamlevine          Adam Levine
# ..              ...                  ...
# 270        zacefron            Zac Efron
# 271       zaynmalik                 zayn
# 272            zedd                 Zedd
# 273         zendaya              Zendaya
# 274  zooeydeschanel      zooey deschanel
#
#                                                   text
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
# [275 rows x 3 columns]

# %%
fb_text_list_gist = df_fb_gist["text"].tolist()
x_text_list_gist = df_x_gist["text"].tolist()

# %%
embeddings_fb_gist = model_gist.encode(fb_text_list_gist, convert_to_tensor=True)
embeddings_x_gist = model_gist.encode(x_text_list_gist, convert_to_tensor=True)

# %%
embeddings_fb_gist = embeddings_fb_gist.cpu().detach().numpy()
embeddings_x_gist = embeddings_x_gist.cpu().detach().numpy()

# %%
gist1 = embeddings_fb_gist.tolist()
gist2 = embeddings_x_gist.tolist()

# %%
df_fb_gist["text_vector"] = gist1

# %%
df_x_gist["text_vector"] = gist2

# %%
data = []
for x in range(len(df_x_gist)):
    for fb in range(len(df_fb_gist)):
        if df_x_gist["user_id"][x] == df_fb_gist["file_name_1"][fb].lower():
            scores = F.cosine_similarity(torch.tensor(df_x_gist["text_vector"][x]), torch.tensor(df_fb_gist["text_vector"][fb]), dim=-1)
            data.append({
                "fb_username": df_fb_gist["username"][fb],
                "x_username": df_x_gist["username"][x],
                "x_userid": df_x_gist["user_id"][x],
                "file_name": df_fb_gist["file_name_2"][fb],
                "cosine": cosine
            })

# %%
data_finish_gist = pd.DataFrame(data)

# %%
data_finish_gist
# Out:
#                                             fb_username       x_username  \
# 0                                Futrj Football Channel       Ronaldinho
# 1                                     Ronaldinho Gaúcho       Ronaldinho
# 2     Trener Dryblingu Piłkarskiego - Piotr "Olo" Ol...       Ronaldinho
# 3                                              Raphinha       Ronaldinho
# 4                                              Raphinha       Ronaldinho
# ...                                                 ...              ...
# 2012                                    Zooey Deschanel  zooey deschanel
# 2013                              Jonathan Silver Scott  zooey deschanel
# 2014                         I Love you Zooey Deschanel  zooey deschanel
# 2015                      Emily Deschanel Fanpage En/Sk  zooey deschanel
# 2016                                Sarah Nelson Makeup  zooey deschanel
#
#             x_userid                       file_name    cosine
# 0       10ronaldinho    10Ronaldinho_facebook_6.json  0.898605
# 1       10ronaldinho    10Ronaldinho_facebook_1.json  0.898605
# 2       10ronaldinho    10Ronaldinho_facebook_4.json  0.898605
# 3       10ronaldinho    10Ronaldinho_facebook_2.json  0.898605
# 4       10ronaldinho    10Ronaldinho_facebook_2.json  0.898605
# ...              ...                             ...       ...
# 2012  zooeydeschanel  ZooeyDeschanel_facebook_1.json  0.898605
# 2013  zooeydeschanel  ZooeyDeschanel_facebook_3.json  0.898605
# 2014  zooeydeschanel  ZooeyDeschanel_facebook_4.json  0.898605
# 2015  zooeydeschanel  ZooeyDeschanel_facebook_6.json  0.898605
# 2016  zooeydeschanel  ZooeyDeschanel_facebook_5.json  0.898605
#
# [2017 rows x 5 columns]

# %%
data_finish_gist = data_finish.groupby("x_userid").agg({
    "fb_username" : "first",
    "cosine" : "max",
    "file_name" : "first"
})

# %%
data_finish_gist
# Out:
#                                 fb_username    cosine  \
# x_userid
# 10ronaldinho         Futrj Football Channel  0.933636
# 143redangel         Angel Locsin Supporters  0.918688
# 50cent                              50 Cent  0.909899
# actuallynph             Neil Patrick Harris  0.937589
# adamlevine                         Maroon 5  0.945554
# ...                                     ...       ...
# zacefron                          Zac Efron  0.940685
# zaynmalik       The Pillowtalker Zayn Malik  0.913868
# zedd                                   Zedd  0.912794
# zendaya                    Celebrity Ladies  0.931439
# zooeydeschanel        Jonathan Silver Scott  0.937947
#
#                                      file_name
# x_userid
# 10ronaldinho      10Ronaldinho_facebook_6.json
# 143redangel        143redangel_facebook_4.json
# 50cent                  50cent_facebook_1.json
# actuallynph        ActuallyNPH_facebook_1.json
# adamlevine          adamlevine_facebook_3.json
# ...                                        ...
# zacefron              ZacEfron_facebook_1.json
# zaynmalik            zaynmalik_facebook_4.json
# zedd                      Zedd_facebook_1.json
# zendaya                Zendaya_facebook_4.json
# zooeydeschanel  ZooeyDeschanel_facebook_3.json
#
# [269 rows x 3 columns]

# %%
true_gist = data_finish[data_finish["file_name"].str[-6] == "1"]

# %% [markdown]
# #### 4.4. Accuracy 2: GIST-small-Embedding-v0

# %%
print("Accuracy of GIST-small-Embedding-v0 model is {0}%".format(round(true_gist.shape[0] / data_finish_gist.shape[0] * 100, 5)))
# Out:
# Accuracy of GIST-small-Embedding-v0 model is 63.56877%

# %% [markdown]
# # METHOD 3: KEYWORD EMBEDDINGS

# %% [markdown]
# ## 1. Positionrank

# %%
df_fb_pr = pd.DataFrame(df_fb_em)
df_x_pr = pd.DataFrame(df_x_em)

# %%
df_fb_pr = df_fb_pr.groupby(['username', "file_name_2"])['text'].agg(lambda x: ' '.join(x)).reset_index()
df_x_pr = df_x_pr.groupby(['user_id','username'])['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
data_pr_x = []
for i in range(0,len(df_x_pr)):
    pos = {'NOUN', 'PROPN', 'ADJ'}
    grammar = "NP: {<ADJ>*<NOUN|PROPN>+}"
    extractor = pke.unsupervised.PositionRank()
    extractor.load_document(input=str(df_x_pr['text'][i]),
                            language='en',
                            normalization='stemming')
    extractor.candidate_selection(grammar=grammar,
                              maximum_word_number=10)
    extractor.candidate_weighting(window=10,
                              pos=pos)
    x_keyphrase=[]
    x_score=[]
    for (keyphrase, score) in extractor.get_n_best(n=1, stemming=True):
        x_keyphrase.append(keyphrase)
        x_score.append(score)
        data_pr_x.append({
                    'x_username': df_x_pr['username'][i],
                    'x_userid' : df_x_pr['username'][i],
                    'x_text': df_x_pr['text'][i],
                    'x_keyphrase': x_keyphrase,
                    'x_score': x_score
                })

# %%
df_x_pr
# Out:
#             user_id             username  \
# 0      10ronaldinho           Ronaldinho
# 1       143redangel         Angel Locsin
# 2            50cent               50cent
# 3       actuallynph  Neil Patrick Harris
# 4        adamlevine          Adam Levine
# ..              ...                  ...
# 270        zacefron            Zac Efron
# 271       zaynmalik                 zayn
# 272            zedd                 Zedd
# 273         zendaya              Zendaya
# 274  zooeydeschanel      zooey deschanel
#
#                                                   text
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
# [275 rows x 3 columns]

# %%
data_pr_fb = []
for i in range(0,len(df_fb_pr)):
    pos = {'NOUN', 'PROPN', 'ADJ'}
    grammar = "NP: {<ADJ>*<NOUN|PROPN>+}"
    extractor = pke.unsupervised.PositionRank()
    extractor.load_document(input=str(df_fb_pr['text'][i]),
                            language='en',
                            normalization='stemming')
    extractor.candidate_selection(grammar=grammar,
                              maximum_word_number=10)
    extractor.candidate_weighting(window=10,
                              pos=pos)
    fb_keyphrase=[]
    fb_score=[]
    for (keyphrase, score) in extractor.get_n_best(n=1, stemming=True):
        fb_keyphrase.append(keyphrase)
        fb_score.append(score)
        data_pr_fb.append({
                    'fb_username': df_fb_pr['username'][i],
                    'fb_text': df_fb_pr['text'][i],
                    'fb_keyphrase': fb_keyphrase,
                    'fb_score': fb_score,
                    'file_name_1': df_fb_pr['file_name_1'][i],
                    'file_name_2': df_fb_pr['file_name_2'][i]
                })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'file_name_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 23
#      16 fb_keyphrase.append(keyphrase)
#      17 fb_score.append(score)
#      18 data_pr_fb.append({
#      19             'fb_username': df_fb_pr['username'][i],
#      20             'fb_text': df_fb_pr['text'][i],
#      21             'fb_keyphrase': fb_keyphrase,
#      22             'fb_score': fb_score,
# ---> 23             'file_name_1': df_fb_pr['file_name_1'][i],
#      24             'file_name_2': df_fb_pr['file_name_2'][i]
#      25         })
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'file_name_1'

# %%
data_pr_x = pd.DataFrame(data_pr_x)
data_pr_x
# Out:
#                 x_username                                             x_text  \
# 0                   50cent  cyber monday sale  storewid sale end tonight s...
# 1                   @jason  mikesalguero think awesom share calendar revie...
# 2                   A Lord  grate it suppos wow excel kind weekend stay sa...
# 3               A.R.Rahman  happi birthday udhaystalin glad part mamannan ...
# 4              Adam Levine   ojala maluma therudeboyz  offici video stream...
# ..                     ...                                                ...
# 270  tyler oakley (parody)  oh wow  shaniatwain lakestreetd  forget that a...
# 271                     ye    first time maralago  rain traffic can't beli...
# 272                   zayn  ask collabor celebr jimihendrix  birthday unex...
# 273        zooey deschanel  love entir convers  im donat  join let know re...
# 274                     👼🏼  blast perform  event kick miami art week watch...
#
#                                            x_keyphrase                x_score
# 0    [lol green light gang bransoncognac lechemindu...   [0.1407137229320425]
# 1            [someth peopl love amp respect laugh amp]  [0.04722670383624279]
# 2    [love day tri happi choic mani realiz believ k...   [0.3024742845936213]
# 3    [happi birthday udhaystalin glad part mamannan...  [0.07252516022626031]
# 4            [iamdamienmu vote vote vote tonight dial]  [0.06373378268493492]
# ..                                                 ...                    ...
# 270        [amp love amp amp gosh brain big amp wrink]  [0.14264694105909392]
# 271                              [first time maralago]  [0.04579993064643104]
# 272  [memyselfandi bestcoversong iheartaward thank ...  [0.05985025202156105]
# 273         [love flower love love happi valentin day]  [0.03877024906434363]
# 274              [event kick miami art week watch bit]  [0.06255434762501054]
#
# [275 rows x 4 columns]

# %%
model_gist = SentenceTransformer("avsolatorio/GIST-small-Embedding-v0", revision=None)

# %%
fb_pr_list_gist = data_pr_fb["fb_keyphrase"].tolist()
x_pr_list_gist = data_pr_x["x_keyphrase"].tolist()

# %%
converted_list_pr_fb = [item[0] for item in fb_pr_list_gist]
converted_list_pr_x = [item[0] for item in x_pr_list_gist]

# %%
embeddings_fb_pr_gist = model_gist.encode(converted_list_pr_fb, convert_to_tensor=True)
embeddings_x_pr_gist = model_gist.encode(converted_list_pr_x, convert_to_tensor=True)

# %%
embeddings_fb_pr_gist = embeddings_fb_pr_gist.cpu().detach().numpy()
embeddings_x_pr_gist = embeddings_x_pr_gist.cpu().detach().numpy()

# %%
gist_pr_fb = embeddings_fb_pr_gist.tolist()
gist_pr_x = embeddings_x_pr_gist.tolist()

# %%
data_pr_fb["text_vector"] = gist_pr_fb
data_pr_x["text_vector"] = gist_pr_x

# %%
data_pr_fb
# Out:
#                               fb_username  \
# 0                                 1 9 9 6
# 1                                 1 9 9 6
# 2                                   1997.
# 3     44th POTUS, his story made history.
# 4     44th POTUS, his story made history.
# ...                                   ...
# 1800                   𝑱𝒖𝒔𝒕𝒊𝒏 𝑩𝒊𝒆𝒃𝒆𝒓 𝑭𝒂𝒏𝒔
# 1801                         𝓩𝓮𝓷𝓭𝓪𝔂𝓪 𝓕𝓪𝓷𝓼
# 1802                                𝙄𝙘𝙤𝙣𝙨
# 1803            𝚅 𝙴 𝚁 𝚂 𝙴 𝚁 𝙴 𝙿 𝚄 𝙱 𝙻 𝙸 𝙲
# 1804                  𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫
#
#                                                 fb_text  \
# 0     cameron diaz mask   popular actor   chang    s...
# 1     cameron diaz mask   popular actor   chang   ic...
# 2     angelina joli  angelina joli  leonardo dicapri...
# 3     queen elizabeth alexandra mari ii majesti made...
# 4     queen elizabeth alexandra mari ii majesti made...
# ...                                                 ...
# 1800  “a gentl word kind look goodnatur smile work w...
# 1801                 wikiofwitchercomdemi moor look ...
# 1802   bella hadid sprayon dress coperni  show alexa...
# 1803  somewher knowkeanelyricsi walk across empti la...
# 1804   merch  grab   second summer new album  back  ...
#
#                                            fb_keyphrase  \
# 0                       [cameron diaz cann film festiv]
# 1               [icon actor movi fouzia hattabiseptemb]
# 2            [leonardo dicaprio kate winslet set titan]
# 3     [celebr happi birthday presid biden happi birt...
# 4     [celebr happi birthday presid biden happi birt...
# ...                                                 ...
# 1800  [justin bieber 𝗝𝗼𝗶𝗻 𝗧𝗵𝗶𝘀 𝗚𝗿𝗼𝘂𝗽 justin bieber b...
# 1801  [loung bikini wikiofwitchercomsofia vergara fl...
# 1802  [kyli jenner kim kardashian kendal jenner kend...
# 1803  [followyoutub channel facebook page songslyr o...
# 1804  [second summer relea fourth studio album calmc...
#
#                    fb_score                    file_name_2  \
# 0     [0.05983370040697931]    LeoDiCaprio_facebook_3.json
# 1      [0.0632936598281836]        Zendaya_facebook_3.json
# 2      [0.2530076599834736]    LeoDiCaprio_facebook_2.json
# 3     [0.17357329099664737]  MichelleObama_facebook_5.json
# 4     [0.17357329099664737]    barackobama_facebook_6.json
# ...                     ...                            ...
# 1800   [0.5298012734056233]   justinbieber_facebook_2.json
# 1801  [0.18062534490329424]        Zendaya_facebook_2.json
# 1802   [0.3238240785428218]    LeoDiCaprio_facebook_4.json
# 1803  [0.05431443673922178]     jason_mraz_facebook_6.json
# 1804  [0.08519177505662727]           5SOS_facebook_3.json
#
#                                             text_vector
# 0     [-0.03853299096226692, -0.008082009851932526, ...
# 1     [-0.0396171510219574, 0.05737358704209328, 0.0...
# 2     [-0.04441084340214729, 0.03955598548054695, 0....
# 3     [-0.12910056114196777, 0.05880581587553024, -0...
# 4     [-0.12910056114196777, 0.05880581587553024, -0...
# ...                                                 ...
# 1800  [-0.03818676993250847, -0.018508898094296455, ...
# 1801  [-0.043392378836870193, -0.047976549714803696,...
# 1802  [-0.0299391932785511, -0.0015602795174345374, ...
# 1803  [-0.045686908066272736, -0.05799580737948418, ...
# 1804  [-0.05415557324886322, -0.021668454632163048, ...
#
# [1805 rows x 6 columns]

# %%
data_pr_x
# Out:
#            x_userid           x_username  \
# 0      10ronaldinho           Ronaldinho
# 1       143redangel         Angel Locsin
# 2            50cent               50cent
# 3       actuallynph  Neil Patrick Harris
# 4        adamlevine          Adam Levine
# ..              ...                  ...
# 270        zacefron            Zac Efron
# 271       zaynmalik                 zayn
# 272            zedd                 Zedd
# 273         zendaya              Zendaya
# 274  zooeydeschanel      zooey deschanel
#
#                                                 x_text  \
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
#                                            x_keyphrase                x_score  \
# 0             [e jogar com ídolo e grand amigo em doi]  [0.09020405427678241]
# 1    [thank sa mga nakipagchikahan sa amin sa pina ...  [0.14146163636709397]
# 2    [lol green light gang bransoncognac lechemindu...   [0.1407137229320425]
# 3     [countri first newslett drop tomorrow wondercad]  [0.04758505772657545]
# 4            [iamdamienmu vote vote vote tonight dial]  [0.06373378268493492]
# ..                                                 ...                    ...
# 270                      [beauti movi togeth love guy]  [0.05258830201341473]
# 271  [memyselfandi bestcoversong iheartaward thank ...  [0.05985025202156105]
# 272            [couragejd love u buddi happi birthday]  [0.06304944028766526]
# 273  [brunomar luxurylaw tommyhilfig thank man appr...  [0.06641876186675881]
# 274         [love flower love love happi valentin day]  [0.03877024906434363]
#
#                                            text_vector
# 0    [-0.013693093322217464, 0.03607881814241409, 0...
# 1    [-0.048325881361961365, 0.058305948972702026, ...
# 2    [-0.04142908379435539, -0.001193844829685986, ...
# 3    [-0.0208944920450449, -0.034327443689107895, 0...
# 4    [-0.0789669081568718, 0.0036763264797627926, 0...
# ..                                                 ...
# 270  [-0.04326127469539642, 0.07125957310199738, 0....
# 271  [-0.05527028068900108, 0.022582782432436943, 0...
# 272  [-0.09585268795490265, 0.03892474249005318, 0....
# 273  [-0.04071503505110741, 0.10008018463850021, 0....
# 274  [-0.05355272814631462, -0.005065518897026777, ...
#
# [275 rows x 6 columns]

# %%
data = []
for x in range(len(data_pr_x)):
    for fb in range(len(data_pr_fb)):
        if data_pr_x["x_userid"][x] == data_pr_fb["file_name_2"][fb].lower()[:-16]:
            cosine = F.cosine_similarity(torch.tensor(data_pr_x["text_vector"][x]), torch.tensor(data_pr_fb["text_vector"][fb]), dim=-1).item()
            data.append({
                "fb_username": data_pr_fb["fb_username"][fb],
                "x_username": data_pr_x["x_username"][x],
                "x_userid": data_pr_x["x_userid"][x],
                "fb_file_name": data_pr_fb["file_name_2"][fb],
                "cosine": cosine
            })

# %%
data_finish_pr_gist = pd.DataFrame(data)
data_finish_pr_gist
# Out:
#                                 fb_username       x_username        x_userid  \
# 0              Brazil ; The Home Of Legends       Ronaldinho    10ronaldinho
# 1                    Futrj Football Channel       Ronaldinho    10ronaldinho
# 2                                  Raphinha       Ronaldinho    10ronaldinho
# 3                         Ronaldinho Gaúcho       Ronaldinho    10ronaldinho
# 4     Ronaldinho: A Legend To Be Remembered       Ronaldinho    10ronaldinho
# ...                                     ...              ...             ...
# 1608             I Love you Zooey Deschanel  zooey deschanel  zooeydeschanel
# 1609                  Jonathan Silver Scott  zooey deschanel  zooeydeschanel
# 1610                    Sarah Nelson Makeup  zooey deschanel  zooeydeschanel
# 1611                        Zooey Deschanel  zooey deschanel  zooeydeschanel
# 1612             Zooey Deschanel Experience  zooey deschanel  zooeydeschanel
#
#                         fb_file_name    cosine
# 0       10Ronaldinho_facebook_3.json  0.676023
# 1       10Ronaldinho_facebook_6.json  0.668486
# 2       10Ronaldinho_facebook_2.json  0.766764
# 3       10Ronaldinho_facebook_1.json  0.814049
# 4       10Ronaldinho_facebook_5.json  0.746551
# ...                              ...       ...
# 1608  ZooeyDeschanel_facebook_4.json  0.638112
# 1609  ZooeyDeschanel_facebook_3.json  0.687953
# 1610  ZooeyDeschanel_facebook_5.json  0.708288
# 1611  ZooeyDeschanel_facebook_1.json  1.000000
# 1612  ZooeyDeschanel_facebook_2.json  0.737571
#
# [1613 rows x 5 columns]

# %%
data_finish_pr_gist = data_finish_pr_gist.groupby("x_userid").agg({
    "fb_username" : "first",
    "cosine" : "max",
    "fb_file_name" : "first"
})

# %%
data_finish_pr_gist
# Out:
#                                             fb_username    cosine  \
# x_userid
# 10ronaldinho               Brazil ; The Home Of Legends  0.814049
# 143redangel                             Alyanna Angeles  0.767110
# 50cent                                          50 Cent  0.797390
# actuallynph     Best Time Ever With Neil Patrick Harris  0.800524
# adamlevine                                  Adam Levine  0.712481
# ...                                                 ...       ...
# zacefron                                   Jessica Alba  0.699006
# zaynmalik                                     Free-Fire  0.772427
# zedd                                       Cosmos Music  0.681543
# zendaya                                         1 9 9 6  0.733082
# zooeydeschanel            Emily Deschanel Fanpage En/Sk  1.000000
#
#                                   fb_file_name
# x_userid
# 10ronaldinho      10Ronaldinho_facebook_3.json
# 143redangel        143redangel_facebook_5.json
# 50cent                  50cent_facebook_1.json
# actuallynph        ActuallyNPH_facebook_4.json
# adamlevine          adamlevine_facebook_1.json
# ...                                        ...
# zacefron              ZacEfron_facebook_4.json
# zaynmalik            zaynmalik_facebook_2.json
# zedd                      Zedd_facebook_5.json
# zendaya                Zendaya_facebook_3.json
# zooeydeschanel  ZooeyDeschanel_facebook_6.json
#
# [270 rows x 3 columns]

# %%
true_gist = data_finish_pr_gist[data_finish_pr_gist["fb_file_name"].str[-6] == "1"]
true_gist
# Out:
#                            fb_username    cosine                  fb_file_name
# x_userid
# 50cent                         50 Cent  0.797390        50cent_facebook_1.json
# adamlevine                 Adam Levine  0.712481    adamlevine_facebook_1.json
# adele                            Adele  0.891185         Adele_facebook_1.json
# akshaykumar               Akshay Kumar  0.684917   akshaykumar_facebook_1.json
# aliaa08                     Alia Bhatt  0.637424       aliaa08_facebook_1.json
# ...                                ...       ...                           ...
# thefarahkhan                Farah Khan  0.720068  TheFarahKhan_facebook_1.json
# tomhanks                     Tom Hanks  0.778263      tomhanks_facebook_1.json
# tripleh       Paul "Triple H" Levesque  0.780488       TripleH_facebook_1.json
# xtina               Christina Aguilera  0.771833         xtina_facebook_1.json
# yuvstrong12               Yuvraj Singh  0.748475   YUVSTRONG12_facebook_1.json
#
# [71 rows x 3 columns]

# %% [markdown]
# ### 1.1. Accuracy

# %%
print("Accuracy of Position rank by GIST-small-Embedding-v0 model is {0}%".format(round(true_gist.shape[0] / data_finish_pr_gist.shape[0] * 100, 5)))
# Out:
# Accuracy of Position rank by GIST-small-Embedding-v0 model is 26.2963%

# %% [markdown]
# ## 2. Yake

# %%
df_fb_yk = pd.DataFrame(df_fb_em)
df_x_yk = pd.DataFrame(df_x_em)

# %%
df_fb_yk
# Out:
#                                      username          user_id  \
# 0                    Forever 5secondsofsummer  587701401348302
# 1                    Forever 5secondsofsummer  587701401348302
# 2                    Forever 5secondsofsummer  587701401348302
# 3                    Forever 5secondsofsummer  587701401348302
# 4       Ronaldinho: A Legend To Be Remembered  258244370945844
# ...                                       ...              ...
# 716645                              YENGSTERS  100044199167866
# 716646                              YENGSTERS  100044199167866
# 716647                              YENGSTERS  100044199167866
# 716648                              YENGSTERS  100044199167866
# 716649                              YENGSTERS  100044199167866
#
#                                                      text    file_name_1  \
# 0                  what whos excit amnesia videolukesmyba           5SOS
# 1       hello im new admin ill wrote imagin peopl want...           5SOS
# 2       admin contest question must answer want becom ...           5SOS
# 3                                                                   5SOS
# 4                             run wing fifa think ronaldo   10Ronaldinho
# ...                                                   ...            ...
# 716645  want win exclus item prelov yeng constantino s...  YengPLUGGEDin
# 716646  tonight  yeng constantinoyoutubecomgood time g...  YengPLUGGEDin
# 716647  new vlog  see yeng constantinoyoutubecomgumawa...  YengPLUGGEDin
# 716648  thank teacher dan  yeng constantinodanvib cebu...  YengPLUGGEDin
# 716649  repost yeng constantinohey hey follow sa kumu ...  YengPLUGGEDin
#
#                           file_name_2
# 0                5SOS_facebook_4.json
# 1                5SOS_facebook_4.json
# 2                5SOS_facebook_4.json
# 3                5SOS_facebook_4.json
# 4        10Ronaldinho_facebook_5.json
# ...                               ...
# 716645  YengPLUGGEDin_facebook_2.json
# 716646  YengPLUGGEDin_facebook_2.json
# 716647  YengPLUGGEDin_facebook_2.json
# 716648  YengPLUGGEDin_facebook_2.json
# 716649  YengPLUGGEDin_facebook_2.json
#
# [716650 rows x 5 columns]

# %%
df_x_yk
# Out:
#             username      user_id  \
# 0         Bill Gates    billgates
# 1         Bill Gates    billgates
# 2         Bill Gates    billgates
# 3         Bill Gates    billgates
# 4         Bill Gates    billgates
# ...              ...          ...
# 265188  arjun rampal  rampalarjun
# 265189  arjun rampal  rampalarjun
# 265190  arjun rampal  rampalarjun
# 265191  arjun rampal  rampalarjun
# 265192  arjun rampal  rampalarjun
#
#                                                      text
# 0       order solv world sanit crisi need smarter toil...
# 1       collabor open access data made seem imposs hea...
# 2       decreas matern mortal lower rate vaccinepreven...
# 3       africa alway heart foundat mission today annou...
# 4       amrefworldwid great thing health within kenya ...
# ...                                                   ...
# 265188                           thank much glad u enjoy
# 265189           ty khaleejtim one didnt run daddi dubai
# 265190                                    yay u guy best
# 265191                                 thank pragya darl
# 265192                                        reel real
#
# [265193 rows x 3 columns]

# %%
df_fb_yk = df_fb_yk.groupby(['username', "file_name_2"])['text'].agg(lambda x: ' '.join(x)).reset_index()
df_x_yk = df_x_yk.groupby(['user_id','username'])['text'].agg(lambda x: ' '.join(x)).reset_index()

# %%
data_yk_x = []
for i in range(0, len(df_x_yk)):
    extractor = pke.unsupervised.YAKE()
    stoplist = stopwords.get('english')
    extractor.load_document(input = str(df_x_yk['text'][i]),
                            language = 'en',
                            stoplist = stoplist,
                            normalization = None)

    extractor.candidate_selection(n = 3)
    window = 2
    use_stems = False
    ex = extractor.candidate_weighting(window = window,
                              use_stems = use_stems)
    threshold = 0.8
    keyphrases = extractor.get_n_best(n=10, threshold=threshold)
    
    x_keyphrase=[]
    x_score=[]
    for (keyphrase, score) in extractor.get_n_best(n=1, stemming=True):
        x_keyphrase.append(keyphrase)
        x_score.append(score)
        data_yk_x.append({
                    'x_username': df_x_yk['username'][i],
                    'x_userid': df_x_yk['user_id'][i],
                    'x_text': df_x_yk['text'][i],
                    'x_keyphrase': x_keyphrase,
                    'x_score': x_score
                })

# %%
data_yk_fb = []
for i in range(0, len(df_fb_yk)):
    extractor = pke.unsupervised.YAKE()
    stoplist = stopwords.get('english')
    extractor.load_document(input = str(df_fb_yk['text'][i]),
                            language = 'en',
                            stoplist = stoplist,
                            normalization = None)

    extractor.candidate_selection(n = 3)
    window = 2
    use_stems = False
    ex = extractor.candidate_weighting(window = window,
                              use_stems = use_stems)
    threshold = 0.8
    keyphrases = extractor.get_n_best(n=10, threshold=threshold)
    
    fb_keyphrase=[]
    fb_score=[]
    for (keyphrase, score) in extractor.get_n_best(n=1, stemming=True):
        fb_keyphrase.append(keyphrase)
        fb_score.append(score)
        data_yk_fb.append({
                    'fb_username': df_fb_yk['username'][i],
                    'fb_text': df_fb_yk['text'][i],
                    'fb_file_name': df_fb_yk['file_name_2'][i],
                    'fb_keyphrase': fb_keyphrase,
                    'fb_score': fb_score
                })

# %%
data_yk_fb = pd.DataFrame(data_yk_fb)
data_yk_fb
# Out:
#                               fb_username  \
# 0                                 1 9 9 6
# 1                                 1 9 9 6
# 2                                   1997.
# 3     44th POTUS, his story made history.
# 4     44th POTUS, his story made history.
# ...                                   ...
# 1806                   𝑱𝒖𝒔𝒕𝒊𝒏 𝑩𝒊𝒆𝒃𝒆𝒓 𝑭𝒂𝒏𝒔
# 1807                         𝓩𝓮𝓷𝓭𝓪𝔂𝓪 𝓕𝓪𝓷𝓼
# 1808                                𝙄𝙘𝙤𝙣𝙨
# 1809            𝚅 𝙴 𝚁 𝚂 𝙴 𝚁 𝙴 𝙿 𝚄 𝙱 𝙻 𝙸 𝙲
# 1810                  𝟓 𝐒𝐞𝐜𝐨𝐧𝐝𝐬 𝐨𝐟 𝐒𝐮𝐦𝐦𝐞𝐫
#
#                                                 fb_text  \
# 0     cameron diaz mask   popular actor   chang    s...
# 1     cameron diaz mask   popular actor   chang   ic...
# 2     angelina joli  angelina joli  leonardo dicapri...
# 3     queen elizabeth alexandra mari ii majesti made...
# 4     queen elizabeth alexandra mari ii majesti made...
# ...                                                 ...
# 1806  “a gentl word kind look goodnatur smile work w...
# 1807                 wikiofwitchercomdemi moor look ...
# 1808   bella hadid sprayon dress coperni  show alexa...
# 1809  somewher knowkeanelyricsi walk across empti la...
# 1810   merch  grab   second summer new album  back  ...
#
#                        fb_file_name                             fb_keyphrase  \
# 0       LeoDiCaprio_facebook_3.json               [icon actor moviesseptemb]
# 1           Zendaya_facebook_3.json               [icon actor moviesseptemb]
# 2       LeoDiCaprio_facebook_2.json                 [leonardo dicaprio kate]
# 3     MichelleObama_facebook_5.json                     [barack obama obama]
# 4       barackobama_facebook_6.json                     [barack obama obama]
# ...                             ...                                      ...
# 1806   justinbieber_facebook_2.json                        [𝗝𝗢𝗜𝗡 𝗧𝗛𝗜𝗦 𝗚𝗥𝗢𝗨𝗣]
# 1807        Zendaya_facebook_2.json  [wikiofwitchercomelizabeth hurley look]
# 1808    LeoDiCaprio_facebook_4.json                     [jenner kyli jenner]
# 1809     jason_mraz_facebook_6.json                  [channel facebook page]
# 1810           5SOS_facebook_3.json                      [second summer new]
#
#                       fb_score
# 0     [1.2534113736167603e-06]
# 1      [1.484367470896525e-06]
# 2      [9.148561488142332e-07]
# 3       [8.85730527616699e-07]
# 4       [8.85730527616699e-07]
# ...                        ...
# 1806  [2.0291174702729002e-08]
# 1807  [2.3288434011263026e-05]
# 1808  [2.5626265032966025e-06]
# 1809   [7.098779724666373e-10]
# 1810   [3.774405155179617e-06]
#
# [1811 rows x 5 columns]

# %%
data_yk_x = pd.DataFrame(data_yk_x)
data_yk_x
# Out:
#               x_username        x_userid  \
# 0             Ronaldinho    10ronaldinho
# 1           Angel Locsin     143redangel
# 2                 50cent          50cent
# 3    Neil Patrick Harris     actuallynph
# 4            Adam Levine      adamlevine
# ..                   ...             ...
# 270            Zac Efron        zacefron
# 271                 zayn       zaynmalik
# 272                 Zedd            zedd
# 273              Zendaya         zendaya
# 274      zooey deschanel  zooeydeschanel
#
#                                                 x_text  \
# 0    mai um rolê bruxo agora com meus parceiro da p...
# 1     new vlog drop theangelandneilchannel today  s...
# 2    cyber monday sale  storewid sale end tonight s...
# 3    tomorrow  anniversari wondercad onedercad chee...
# 4     ojala maluma therudeboyz  offici video stream...
# ..                                                 ...
# 270  let fix keep make beauti movi togeth love guy ...
# 271  ask collabor celebr jimihendrix  birthday unex...
# 272  couragejd proud buddi thankyoux transientlab  ...
# 273   luxurylaw loeweoffici    step away music quit...
# 274  love entir convers  im donat  join let know re...
#
#                             x_keyphrase                   x_score
# 0                    [com meu parceiro]  [2.5823788524862365e-05]
# 1                          [post photo]  [3.3980306889807365e-06]
# 2    [gang bransoncognac lecheminduroi]   [5.176929645322569e-08]
# 3                      [happi new year]   [6.891414361150879e-06]
# 4                      [vote vote vote]  [4.6054359543475463e-07]
# ..                                  ...                       ...
# 270               [thank birthday love]  [1.0801062395036388e-05]
# 271                [thank support love]  [1.4136759071548722e-05]
# 272                       [yes yes yes]  [3.5595428178318704e-06]
# 273                 [thank thank thank]   [9.108413177042713e-06]
# 274                [west coast newgirl]  [4.0722299306446654e-06]
#
# [275 rows x 5 columns]

# %%
fb_yk_list_gist = data_yk_fb["fb_keyphrase"].tolist()
x_yk_list_gist = data_yk_x["x_keyphrase"].tolist()

# %%
converted_list_yk_fb = [item[0] for item in fb_yk_list_gist]
converted_list_yk_x = [item[0] for item in x_yk_list_gist]

# %%
embeddings_fb_yk_gist = model_gist.encode(converted_list_yk_fb, convert_to_tensor=True)
embeddings_x_yk_gist = model_gist.encode(converted_list_yk_x, convert_to_tensor=True)

# %%
gist_yk_fb = embeddings_fb_yk_gist.tolist()
gist_yk_x = embeddings_x_yk_gist.tolist()

# %%
data_yk_fb["text_vector"] = gist_yk_fb
data_yk_x["text_vector"] = gist_yk_x

# %%
data_yk = []
for x in range(len(data_yk_x)):
    for fb in range(len(data_yk_fb)):
        if data_yk_x["x_userid"][x] == data_yk_fb["fb_file_name"][fb].lower()[:-16]:
            cosine = F.cosine_similarity(torch.tensor(data_yk_x["text_vector"][x]), torch.tensor(data_yk_fb["text_vector"][fb]), dim=-1).item()
            data_yk.append({
                "fb_username": data_yk_fb["fb_username"][fb],
                "x_username": data_yk_x["x_username"][x],
                "x_userid": data_yk_x["x_userid"][x],
                "fb_file_name": data_yk_fb["fb_file_name"][fb],
                "cosine": cosine
            })

# %%
data_yk = pd.DataFrame(data_yk)

# %%
data_finish_yk_gist = data_yk.groupby("x_userid").agg({
    "fb_username" : "first",
    "cosine" : "max",
    "fb_file_name" : "first"
})

# %%
true_yk_gist = data_finish_yk_gist[data_finish_pr_gist["fb_file_name"].str[-6] == "1"]
true_yk_gist
# Out:
#                            fb_username    cosine                  fb_file_name
# x_userid
# 50cent                         50 Cent  0.912364        50cent_facebook_1.json
# adamlevine                 Adam Levine  0.699378    adamlevine_facebook_1.json
# adele                            Adele  1.000000         Adele_facebook_1.json
# akshaykumar               Akshay Kumar  0.684729   akshaykumar_facebook_1.json
# aliaa08                     Alia Bhatt  0.651843       aliaa08_facebook_1.json
# ...                                ...       ...                           ...
# thefarahkhan                Farah Khan  1.000000  TheFarahKhan_facebook_1.json
# tomhanks                     Tom Hanks  0.811401      tomhanks_facebook_1.json
# tripleh       Paul "Triple H" Levesque  0.731107       TripleH_facebook_1.json
# xtina               Christina Aguilera  0.800555         xtina_facebook_1.json
# yuvstrong12               Yuvraj Singh  1.000000   YUVSTRONG12_facebook_1.json
#
# [71 rows x 3 columns]

# %% [markdown]
# ### 2.1. Accuracy

# %%
print("Accuracy of Yake by GIST-small-Embedding-v0 model is {0}%".format(round(true_yk_gist.shape[0] / data_finish_yk_gist.shape[0] * 100, 5)))
# Out:
# Accuracy of Yake by GIST-small-Embedding-v0 model is 26.2963%
